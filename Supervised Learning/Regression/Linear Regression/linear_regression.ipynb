# %% [markdown]
# # Linear Regression Algo Demo

# %% [markdown]
# ## Simple Linear Regression (With 1 Independent Variable(x) & 1 Dependent Variable(y))

# %% [markdown]
# ### Step 1: Import the Dataset

# %%
import pandas as pd
data = pd.read_csv("Boston1.csv")
data
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
data.shape
# Out:
# (506, 14)

# %%
data.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
data.tail()
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#       black  lstat  medv
# 501  391.99   9.67  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %%
data.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       black  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# ### Step 2: Figuring Out Independent(x) & dependent(y) Variable

# %% [markdown]
# ##### first we take the 1 as a independent variable and 1 as a dependent variable which are last two colomns

# %%
data_ = data.loc[:,['lstat','medv']]
data_.head()
# Out:
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %% [markdown]
# #### Visualizing variables

# %%
import matplotlib.pyplot as plt
data_.plot(x='lstat',y='medv',style='o')
plt.xlabel('lstat')
plt.ylabel('medv')
plt.show()

# %% [markdown]
# #### Preparing Data

# %%
x = pd.DataFrame(data_['lstat'])
y = pd.DataFrame(data_['medv'])

# %%
x.size,y.size
# Out:
# (506, 506)

# %% [markdown]
# ### Step 3: Split the dataset into x_train, x_test, y_train & y_test

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2, random_state=1)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(x_test.shape)
# Out:
# (404, 1)
# (102, 1)
# (404, 1)
# (102, 1)

# %% [markdown]
# ### Step 4: Creating the Model using Scikit Learn Library

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# %% [markdown]
# ### Step 5: Train the Model

# %%
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)   # it basically the 'c' in 'y=mx+c'
# Out:
# [34.33497839]

# %%
print(regressor.coef_)  # it basically the 'm' in 'y=mx+c'
# Out:
# [[-0.92441715]]

# %% [markdown]
# ### Step 6: Predicting using the testing dataset

# %%
y_pred = regressor.predict(x_test)
y_pred = pd.DataFrame(y_pred,columns=['Predicted'])

# %%
y_pred
# Out:
#      Predicted
# 0    27.374117
# 1    27.697663
# 2    16.955936
# 3    26.847199
# 4    24.915168
# ..         ...
# 97   26.791734
# 98   30.507891
# 99   22.317555
# 100  19.830873
# 101  16.909715
#
# [102 rows x 1 columns]

# %%
y_test
# Out:
#      medv
# 307  28.2
# 343  23.9
# 47   16.6
# 67   22.0
# 362  20.8
# ..    ...
# 92   22.9
# 224  44.8
# 110  21.7
# 426  10.2
# 443  15.4
#
# [102 rows x 1 columns]

# %% [markdown]
# ### Step 7: Evaluate the performance of Model

# %%
from sklearn import metrics
import numpy as np
print('Mean Absolute Error:',metrics.mean_absolute_error(y_test,y_pred))
print('Mean Squared Error:',metrics.mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error:',np.sqrt(metrics.mean_absolute_error(y_test,y_pred)))
# Out:
# Mean Absolute Error: 5.078127727696937
# Mean Squared Error: 46.994820919547124
# Root Mean Squared Error: 2.2534701523865226

# %%
# r^2 value 
r2 = regressor.score(x_test, y_test)
print(f"R-squared value: {r2:.4f}")
# Out:
# R-squared value: 0.5245

# %% [markdown]
# ## Multiple Linear Regression (With More than 1 Independent Variable(x) & 1 Dependent Variable(y))

# %% [markdown]
# ### Step 1: Import the Dataset

# %%
dataset = pd.read_csv("Boston1.csv")
dataset
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
dataset.shape
# Out:
# (506, 14)

# %%
dataset.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
dataset.tail()
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#       black  lstat  medv
# 501  391.99   9.67  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %%
dataset.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       black  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# ### Step 2: Figuring Out Independent(x) & dependent(y) Variables

# %%
X = pd.DataFrame(dataset.iloc[:,:-1])
y = pd.DataFrame(dataset['medv'])

# %%
X.shape
# Out:
# (506, 13)

# %%
y.shape
# Out:
# (506, 1)

# %% [markdown]
# ### Step 3: Split the dataset into x_train, x_test, y_train & y_test

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2, random_state=1)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (404, 13)
# (102, 13)
# (404, 1)
# (102, 1)

# %% [markdown]
# ### Step 4: Creating the Model using Scikit Learn Library

# %%
from sklearn.linear_model import LinearRegression
mulreg = LinearRegression()

# %% [markdown]
# ### Step 5: Train the Model

# %%
mulreg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
m = pd.DataFrame(mulreg.coef_,index=['Coeffienct']).transpose()
a = pd.DataFrame(X.columns,columns=['Attribute'])

# %%
m
# Out:
#     Coeffienct
# 0    -0.112387
# 1     0.058059
# 2     0.018359
# 3     2.129978
# 4   -19.581101
# 5     3.095462
# 6     0.004453
# 7    -1.500476
# 8     0.305359
# 9    -0.011123
# 10   -0.989008
# 11    0.007321
# 12   -0.544645

# %%
a
# Out:
#    Attribute
# 0       crim
# 1         zn
# 2      indus
# 3       chas
# 4        nox
# 5         rm
# 6        age
# 7        dis
# 8        rad
# 9        tax
# 10   ptratio
# 11     black
# 12     lstat

# %%
coef = pd.concat([m,a],axis=1,join='inner')
coef
# Out:
#     Coeffienct Attribute
# 0    -0.112387      crim
# 1     0.058059        zn
# 2     0.018359     indus
# 3     2.129978      chas
# 4   -19.581101       nox
# 5     3.095462        rm
# 6     0.004453       age
# 7    -1.500476       dis
# 8     0.305359       rad
# 9    -0.011123       tax
# 10   -0.989008   ptratio
# 11    0.007321     black
# 12   -0.544645     lstat

# %%
print(mulreg.intercept_)
# Out:
# [42.93352585]

# %% [markdown]
# ### Step 6: Predicting using the testing dataset

# %%
y_pred = mulreg.predict(X_test)
y_pred = pd.DataFrame(y_pred,columns=['Predicted'])

# %%
y_pred
# Out:
#      Predicted
# 0    32.655032
# 1    28.093495
# 2    18.029018
# 3    21.476716
# 4    18.825439
# ..         ...
# 97   29.089918
# 98   37.119379
# 99   20.532710
# 100  17.368400
# 101  17.713993
#
# [102 rows x 1 columns]

# %%
y_test
# Out:
#      medv
# 307  28.2
# 343  23.9
# 47   16.6
# 67   22.0
# 362  20.8
# ..    ...
# 92   22.9
# 224  44.8
# 110  21.7
# 426  10.2
# 443  15.4
#
# [102 rows x 1 columns]

# %% [markdown]
# ### Step 7: Evaluate the performance of Model

# %%
print('Mean Absolute Error:',metrics.mean_absolute_error(y_test,y_pred))
print('Mean Squared Error:',metrics.mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error:',np.sqrt(metrics.mean_absolute_error(y_test,y_pred)))
# Out:
# Mean Absolute Error: 3.7507121808389177
# Mean Squared Error: 23.380836480270055
# Root Mean Squared Error: 1.9366755486758533

# %%
# r^2 value 
r2 = mulreg.score(X_test, y_test)
print(f"R-squared value: {r2:.4f}")
# Out:
# R-squared value: 0.7634
